# %% [markdown]
# <a href="https://colab.research.google.com/github/hilini/Temporary_add_to_version_control/blob/master/Copy_of_cifar100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 코랩 메뉴 -> 수정 -> 노트 설정 -> 하드웨어 가속기 GPU 권장(행렬 연산이 많기 때문)

# %% [markdown]
# 구글 드라이브 연동

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# 폴더 경로 설정

# %%
workspace_path = '/gdrive/My Drive/Colab Notebooks'

# %% [markdown]
# 필요 패키지 로드

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# 결과 재현을 위한 설정

# %%
seed = 719
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

use_cuda = torch.cuda.is_available()  
device = torch.device("cuda" if use_cuda else "cpu") 
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {} 
print("set vars and device done")
# Out:
# set vars and device done

# %% [markdown]
# 합성곱 신경망(CNN) 정의

# %%
import torchvision.models as models

class AlexNet(nn.Module):
    def __init__(self):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(64, 192, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 2 * 2, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, 100),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), 256 * 2 * 2)
        x = self.classifier(x)
        return x

print("init model done")
# Out:
# init model done

# %%
##   AverageMeter 정의
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count



###   학습, 테스트용 함수 정의
def train(log_interval, model, device, train_loader, optimizer, epoch):
    model.train()  
    summary_loss = AverageMeter()  
    summary_acc = AverageMeter()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)  
        optimizer.zero_grad() 
        output = model(data)  
        loss = criterion(output, target) 
        loss.backward()  
        optimizer.step() 
        summary_loss.update(loss.detach().item()) 
        pred = output.argmax(dim=1, keepdim=True)  
        correct = pred.eq(target.view_as(pred)).sum().item()
        summary_acc.update(correct / data.size(0)) 
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tAverage loss: {:.6f}, Accuracy: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), summary_loss.avg, summary_acc.avg))
            
    return summary_loss.avg, summary_acc.avg

def test(log_interval, model, device, test_loader):
    model.eval() 
    summary_loss = AverageMeter() 
    summary_acc = AverageMeter() 
    with torch.no_grad():  
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)  
            output = model(data) 
            loss = criterion(output, target)  
            summary_loss.update(loss.detach().item())  
            pred = output.argmax(dim=1, keepdim=True)  
            correct = pred.eq(target.view_as(pred)).sum().item() 
            summary_acc.update(correct / data.size(0))  

    print('\nTest set: Average loss: {:.4f}, Accuracy: {:.6f}\n'.format
          (summary_loss.avg, summary_acc.avg))  

    return summary_loss.avg, summary_acc.avg

# %%
##   모델 학습을 위한 하이퍼파라미터 셋팅
batch_size = 124
test_batch_size = 1000
max_epochs = 50
lr = 0.01
momentum = 0.9
log_interval = 200

##   데이터 로더 정의 (학습용, 테스트용 따로 정의)
transform_train = transforms.Compose([
                                      transforms.RandomCrop(32, padding=4),
                                      transforms.RandomHorizontalFlip(p=0.5),
                                      transforms.ToTensor(), 
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])  

transform_test = transforms.Compose([
                                      transforms.ToTensor(), 
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])  


train_loader = torch.utils.data.DataLoader(
  datasets.CIFAR100(os.path.join(workspace_path, 'data'), train=True, download=True, 
                   transform=transform_train ), 
    batch_size = batch_size, shuffle=True, drop_last=True, **kwargs) 


test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR100(os.path.join(workspace_path, 'data'), train=False, download=True,
                         transform=transform_test), 
    batch_size=test_batch_size, shuffle=False, **kwargs)


##   모델, 최적화 알고리즘, 손실 함수 정의
#model = AlexNet().to(device)
model = models.resnet18().to(device)
#model= models.alexnet().to(device)
#model = models.vgg16().to(device)
print(model)

optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
criterion = nn.CrossEntropyLoss()


##   학습, 테스트, 모델 저장 수행
best_acc = 0
best_epoch = 0
for epoch in range(1, max_epochs+1):
    start_tic = time.time()
    train_loss, train_acc = train(log_interval, model, device, train_loader, optimizer, epoch)
    test_loss, test_acc = test(log_interval, model, device, test_loader)
   
    if test_acc > best_acc:
        best_acc = test_acc
        best_epoch = epoch
        # torch.save(model, os.path.join(workspace_path, f'cifar10_cnn_model_best_acc_{best_epoch}-epoch.pt'))
        # print(f'# save model: cifar10_cnn_model_best_acc_{best_epoch}-epoch.pt\n')
        print('best_acc : ',best_acc,'\n')
    print('epoch time : ', time.time()-start_tic,'\n')

print(f'\n\n# Best accuracy model({best_acc * 100:.2f}%)')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )
# Train Epoch: 1 [0/50000 (0%)]	Average loss: 7.167854, Accuracy: 0.000000
# Train Epoch: 1 [24800/50000 (50%)]	Average loss: 4.257900, Accuracy: 0.083052
# Train Epoch: 1 [49600/50000 (99%)]	Average loss: 3.922449, Accuracy: 0.117489
#
# Test set: Average loss: 3.4037, Accuracy: 0.186800
#
# best_acc :  0.1868
#
# epoch time :  20.83066177368164
#
# Train Epoch: 2 [0/50000 (0%)]	Average loss: 3.718202, Accuracy: 0.104839
# Train Epoch: 2 [24800/50000 (50%)]	Average loss: 3.328131, Accuracy: 0.193428
# Train Epoch: 2 [49600/50000 (99%)]	Average loss: 3.256101, Accuracy: 0.207164
#
# Test set: Average loss: 3.0693, Accuracy: 0.238000
#
# best_acc :  0.23800000000000004
#
# epoch time :  20.66204261779785
#
# Train Epoch: 3 [0/50000 (0%)]	Average loss: 2.988178, Accuracy: 0.258065
# Train Epoch: 3 [24800/50000 (50%)]	Average loss: 3.011773, Accuracy: 0.251003
# Train Epoch: 3 [49600/50000 (99%)]	Average loss: 2.981352, Accuracy: 0.256637
#
# Test set: Average loss: 2.8117, Accuracy: 0.292300
#
# best_acc :  0.29229999999999995
#
# epoch time :  20.265064239501953
#
# Train Epoch: 4 [0/50000 (0%)]	Average loss: 3.025658, Accuracy: 0.233871
# Train Epoch: 4 [24800/50000 (50%)]	Average loss: 2.778142, Accuracy: 0.294255
# Train Epoch: 4 [49600/50000 (99%)]	Average loss: 2.754930, Accuracy: 0.299574
#
# Test set: Average loss: 2.6646, Accuracy: 0.324000
#
# best_acc :  0.32399999999999995
#
# epoch time :  20.237292528152466
#
# Train Epoch: 5 [0/50000 (0%)]	Average loss: 2.380930, Accuracy: 0.346774
# Train Epoch: 5 [24800/50000 (50%)]	Average loss: 2.602394, Accuracy: 0.326633
# Train Epoch: 5 [49600/50000 (99%)]	Average loss: 2.584144, Accuracy: 0.331570
#
# Test set: Average loss: 2.5923, Accuracy: 0.341200
#
# best_acc :  0.34120000000000006
#
# epoch time :  20.357959032058716
#
# Train Epoch: 6 [0/50000 (0%)]	Average loss: 2.250201, Accuracy: 0.346774
# Train Epoch: 6 [24800/50000 (50%)]	Average loss: 2.458939, Accuracy: 0.356042
# Train Epoch: 6 [49600/50000 (99%)]	Average loss: 2.446049, Accuracy: 0.360812
#
# Test set: Average loss: 2.5940, Accuracy: 0.342000
#
# best_acc :  0.342
#
# epoch time :  20.16624164581299
#
# Train Epoch: 7 [0/50000 (0%)]	Average loss: 2.093421, Accuracy: 0.451613
# Train Epoch: 7 [24800/50000 (50%)]	Average loss: 2.322984, Accuracy: 0.384810
# Train Epoch: 7 [49600/50000 (99%)]	Average loss: 2.315305, Accuracy: 0.388545
#
# Test set: Average loss: 2.4836, Accuracy: 0.376200
#
# best_acc :  0.3762
#
# epoch time :  20.461589813232422
#
# Train Epoch: 8 [0/50000 (0%)]	Average loss: 2.172586, Accuracy: 0.419355
# Train Epoch: 8 [24800/50000 (50%)]	Average loss: 2.205374, Accuracy: 0.412173
# Train Epoch: 8 [49600/50000 (99%)]	Average loss: 2.206933, Accuracy: 0.413482
#
# Test set: Average loss: 2.2897, Accuracy: 0.408400
#
# best_acc :  0.4084
#
# epoch time :  20.41857361793518
#
# Train Epoch: 9 [0/50000 (0%)]	Average loss: 2.180562, Accuracy: 0.427419
# Train Epoch: 9 [24800/50000 (50%)]	Average loss: 2.085308, Accuracy: 0.440860
# Train Epoch: 9 [49600/50000 (99%)]	Average loss: 2.117271, Accuracy: 0.431944
#
# Test set: Average loss: 2.2877, Accuracy: 0.410400
#
# best_acc :  0.4104
#
# epoch time :  20.30107617378235
#
# Train Epoch: 10 [0/50000 (0%)]	Average loss: 1.927285, Accuracy: 0.516129
# Train Epoch: 10 [24800/50000 (50%)]	Average loss: 2.016463, Accuracy: 0.451493
# Train Epoch: 10 [49600/50000 (99%)]	Average loss: 2.034145, Accuracy: 0.449783
#
# Test set: Average loss: 2.1924, Accuracy: 0.428100
#
# best_acc :  0.42810000000000004
#
# epoch time :  20.67374277114868
#
# Train Epoch: 11 [0/50000 (0%)]	Average loss: 1.856716, Accuracy: 0.451613
# Train Epoch: 11 [24800/50000 (50%)]	Average loss: 1.927223, Accuracy: 0.474803
# Train Epoch: 11 [49600/50000 (99%)]	Average loss: 1.944161, Accuracy: 0.469089
#
# Test set: Average loss: 2.1491, Accuracy: 0.435800
#
# best_acc :  0.43579999999999997
#
# epoch time :  20.37591862678528
#
# Train Epoch: 12 [0/50000 (0%)]	Average loss: 1.822824, Accuracy: 0.516129
# Train Epoch: 12 [24800/50000 (50%)]	Average loss: 1.858969, Accuracy: 0.487442
# Train Epoch: 12 [49600/50000 (99%)]	Average loss: 1.875749, Accuracy: 0.485601
#
# Test set: Average loss: 2.1833, Accuracy: 0.437800
#
# best_acc :  0.4378
#
# epoch time :  20.587789058685303
#
# Train Epoch: 13 [0/50000 (0%)]	Average loss: 1.870009, Accuracy: 0.483871
# Train Epoch: 13 [24800/50000 (50%)]	Average loss: 1.795562, Accuracy: 0.505176
# Train Epoch: 13 [49600/50000 (99%)]	Average loss: 1.805239, Accuracy: 0.502031
#
# Test set: Average loss: 2.1251, Accuracy: 0.444800
#
# best_acc :  0.44480000000000003
#
# epoch time :  20.540285110473633
#
# Train Epoch: 14 [0/50000 (0%)]	Average loss: 1.669898, Accuracy: 0.516129
# Train Epoch: 14 [24800/50000 (50%)]	Average loss: 1.705636, Accuracy: 0.522147
# Train Epoch: 14 [49600/50000 (99%)]	Average loss: 1.739580, Accuracy: 0.515626
#
# Test set: Average loss: 2.0979, Accuracy: 0.458800
#
# best_acc :  0.4588
#
# epoch time :  20.47621250152588
#
# Train Epoch: 15 [0/50000 (0%)]	Average loss: 1.388234, Accuracy: 0.540323
# Train Epoch: 15 [24800/50000 (50%)]	Average loss: 1.646624, Accuracy: 0.530613
# Train Epoch: 15 [49600/50000 (99%)]	Average loss: 1.672539, Accuracy: 0.529221
#
# Test set: Average loss: 2.1470, Accuracy: 0.451800
#
# epoch time :  20.235271692276
#
# Train Epoch: 16 [0/50000 (0%)]	Average loss: 1.456644, Accuracy: 0.588710
# Train Epoch: 16 [24800/50000 (50%)]	Average loss: 1.596163, Accuracy: 0.547906
# Train Epoch: 16 [49600/50000 (99%)]	Average loss: 1.616100, Accuracy: 0.543017
#
# Test set: Average loss: 2.0750, Accuracy: 0.473800
#
# best_acc :  0.47380000000000005
#
# epoch time :  20.418325901031494
#
# Train Epoch: 17 [0/50000 (0%)]	Average loss: 1.296031, Accuracy: 0.629032
# Train Epoch: 17 [24800/50000 (50%)]	Average loss: 1.524293, Accuracy: 0.568849
# Train Epoch: 17 [49600/50000 (99%)]	Average loss: 1.550460, Accuracy: 0.560454
#
# Test set: Average loss: 2.1084, Accuracy: 0.464900
#
# epoch time :  20.416930198669434
#
# Train Epoch: 18 [0/50000 (0%)]	Average loss: 1.305421, Accuracy: 0.604839
# Train Epoch: 18 [24800/50000 (50%)]	Average loss: 1.463810, Accuracy: 0.578318
# Train Epoch: 18 [49600/50000 (99%)]	Average loss: 1.498359, Accuracy: 0.571957
#
# Test set: Average loss: 2.0731, Accuracy: 0.472200
#
# epoch time :  20.584851503372192
#
# Train Epoch: 19 [0/50000 (0%)]	Average loss: 1.159531, Accuracy: 0.685484
# Train Epoch: 19 [24800/50000 (50%)]	Average loss: 1.412378, Accuracy: 0.593524
# Train Epoch: 19 [49600/50000 (99%)]	Average loss: 1.439459, Accuracy: 0.587342
#
# Test set: Average loss: 2.0467, Accuracy: 0.481600
#
# best_acc :  0.4815999999999999
#
# epoch time :  20.607565879821777
#
# Train Epoch: 20 [0/50000 (0%)]	Average loss: 1.144482, Accuracy: 0.620968
# Train Epoch: 20 [24800/50000 (50%)]	Average loss: 1.333114, Accuracy: 0.615471
# Train Epoch: 20 [49600/50000 (99%)]	Average loss: 1.382104, Accuracy: 0.601339
#
# Test set: Average loss: 2.0602, Accuracy: 0.480500
#
# epoch time :  20.383347034454346
#
# Train Epoch: 21 [0/50000 (0%)]	Average loss: 1.280874, Accuracy: 0.612903
# Train Epoch: 21 [24800/50000 (50%)]	Average loss: 1.304764, Accuracy: 0.620205
# Train Epoch: 21 [49600/50000 (99%)]	Average loss: 1.339369, Accuracy: 0.611616
#
# Test set: Average loss: 2.0920, Accuracy: 0.480100
#
# epoch time :  20.506592750549316
#
# Train Epoch: 22 [0/50000 (0%)]	Average loss: 1.329646, Accuracy: 0.556452
# Train Epoch: 22 [24800/50000 (50%)]	Average loss: 1.248818, Accuracy: 0.633767
# Train Epoch: 22 [49600/50000 (99%)]	Average loss: 1.285652, Accuracy: 0.624346
#
# Test set: Average loss: 2.0788, Accuracy: 0.489300
#
# best_acc :  0.4892999999999999
#
# epoch time :  20.56839418411255
#
# Train Epoch: 23 [0/50000 (0%)]	Average loss: 1.068762, Accuracy: 0.685484
# Train Epoch: 23 [24800/50000 (50%)]	Average loss: 1.185778, Accuracy: 0.651380
# Train Epoch: 23 [49600/50000 (99%)]	Average loss: 1.233885, Accuracy: 0.636936
#
# Test set: Average loss: 2.2222, Accuracy: 0.472200
#
# epoch time :  20.78053593635559
#
# Train Epoch: 24 [0/50000 (0%)]	Average loss: 1.238169, Accuracy: 0.629032
# Train Epoch: 24 [24800/50000 (50%)]	Average loss: 1.141524, Accuracy: 0.661692
# Train Epoch: 24 [49600/50000 (99%)]	Average loss: 1.178275, Accuracy: 0.650853
#
# Test set: Average loss: 2.1231, Accuracy: 0.484900
#
# epoch time :  20.358760118484497
#
# Train Epoch: 25 [0/50000 (0%)]	Average loss: 1.244526, Accuracy: 0.677419
# Train Epoch: 25 [24800/50000 (50%)]	Average loss: 1.088334, Accuracy: 0.673207
# Train Epoch: 25 [49600/50000 (99%)]	Average loss: 1.125886, Accuracy: 0.662698
#
# Test set: Average loss: 2.2211, Accuracy: 0.473700
#
# epoch time :  20.543233633041382
#
# Train Epoch: 26 [0/50000 (0%)]	Average loss: 0.988455, Accuracy: 0.693548
# Train Epoch: 26 [24800/50000 (50%)]	Average loss: 1.034165, Accuracy: 0.691703
# Train Epoch: 26 [49600/50000 (99%)]	Average loss: 1.075820, Accuracy: 0.678405
#
# Test set: Average loss: 2.2190, Accuracy: 0.484400
#
# epoch time :  20.323036909103394
#
# Train Epoch: 27 [0/50000 (0%)]	Average loss: 0.711845, Accuracy: 0.774194
# Train Epoch: 27 [24800/50000 (50%)]	Average loss: 0.985148, Accuracy: 0.699888
# Train Epoch: 27 [49600/50000 (99%)]	Average loss: 1.025753, Accuracy: 0.689124
#
# Test set: Average loss: 2.2196, Accuracy: 0.485100
#
# epoch time :  20.578665018081665
#
# Train Epoch: 28 [0/50000 (0%)]	Average loss: 0.860911, Accuracy: 0.741935
# Train Epoch: 28 [24800/50000 (50%)]	Average loss: 0.934918, Accuracy: 0.713208
# Train Epoch: 28 [49600/50000 (99%)]	Average loss: 0.989792, Accuracy: 0.699039
#
# Test set: Average loss: 2.1672, Accuracy: 0.486200
#
# epoch time :  20.366203546524048
#
# Train Epoch: 29 [0/50000 (0%)]	Average loss: 0.727763, Accuracy: 0.790323
# Train Epoch: 29 [24800/50000 (50%)]	Average loss: 0.890892, Accuracy: 0.726890
# Train Epoch: 29 [49600/50000 (99%)]	Average loss: 0.936859, Accuracy: 0.714605
#
# Test set: Average loss: 2.2168, Accuracy: 0.492700
#
# best_acc :  0.49269999999999986
#
# epoch time :  20.534560918807983
#
# Train Epoch: 30 [0/50000 (0%)]	Average loss: 0.940105, Accuracy: 0.733871
# Train Epoch: 30 [24800/50000 (50%)]	Average loss: 0.853050, Accuracy: 0.738004
# Train Epoch: 30 [49600/50000 (99%)]	Average loss: 0.895275, Accuracy: 0.724580
#
# Test set: Average loss: 2.2526, Accuracy: 0.484800
#
# epoch time :  20.25725793838501
#
# Train Epoch: 31 [0/50000 (0%)]	Average loss: 0.814205, Accuracy: 0.741935
# Train Epoch: 31 [24800/50000 (50%)]	Average loss: 0.797531, Accuracy: 0.755336
# Train Epoch: 31 [49600/50000 (99%)]	Average loss: 0.849535, Accuracy: 0.738899
#
# Test set: Average loss: 2.2560, Accuracy: 0.493700
#
# best_acc :  0.4936999999999999
#
# epoch time :  20.509999752044678
#
# Train Epoch: 32 [0/50000 (0%)]	Average loss: 0.593159, Accuracy: 0.830645
# Train Epoch: 32 [24800/50000 (50%)]	Average loss: 0.783986, Accuracy: 0.758225
# Train Epoch: 32 [49600/50000 (99%)]	Average loss: 0.814588, Accuracy: 0.747908
#
# Test set: Average loss: 2.2752, Accuracy: 0.491600
#
# epoch time :  20.260968923568726
#
# Train Epoch: 33 [0/50000 (0%)]	Average loss: 0.643275, Accuracy: 0.838710
# Train Epoch: 33 [24800/50000 (50%)]	Average loss: 0.735764, Accuracy: 0.771987
# Train Epoch: 33 [49600/50000 (99%)]	Average loss: 0.774207, Accuracy: 0.760800
#
# Test set: Average loss: 2.3478, Accuracy: 0.491300
#
# epoch time :  20.499824047088623
#
# Train Epoch: 34 [0/50000 (0%)]	Average loss: 0.717459, Accuracy: 0.758065
# Train Epoch: 34 [24800/50000 (50%)]	Average loss: 0.679096, Accuracy: 0.786752
# Train Epoch: 34 [49600/50000 (99%)]	Average loss: 0.729841, Accuracy: 0.768100
#
# Test set: Average loss: 2.3763, Accuracy: 0.494600
#
# best_acc :  0.4946
#
# epoch time :  20.482352256774902
#
# Train Epoch: 35 [0/50000 (0%)]	Average loss: 0.796404, Accuracy: 0.733871
# Train Epoch: 35 [24800/50000 (50%)]	Average loss: 0.649518, Accuracy: 0.793853
# Train Epoch: 35 [49600/50000 (99%)]	Average loss: 0.692633, Accuracy: 0.781715
#
# Test set: Average loss: 2.3877, Accuracy: 0.490800
#
# epoch time :  20.613635540008545
#
# Train Epoch: 36 [0/50000 (0%)]	Average loss: 0.531627, Accuracy: 0.838710
# Train Epoch: 36 [24800/50000 (50%)]	Average loss: 0.610505, Accuracy: 0.806612
# Train Epoch: 36 [49600/50000 (99%)]	Average loss: 0.662208, Accuracy: 0.789578
#
# Test set: Average loss: 2.4335, Accuracy: 0.485800
#
# epoch time :  20.572365045547485
#
# Train Epoch: 37 [0/50000 (0%)]	Average loss: 0.895212, Accuracy: 0.677419
# Train Epoch: 37 [24800/50000 (50%)]	Average loss: 0.590278, Accuracy: 0.814837
# Train Epoch: 37 [49600/50000 (99%)]	Average loss: 0.625606, Accuracy: 0.802912
#
# Test set: Average loss: 2.4645, Accuracy: 0.493200
#
# epoch time :  20.580374002456665
#
# Train Epoch: 38 [0/50000 (0%)]	Average loss: 0.607349, Accuracy: 0.830645
# Train Epoch: 38 [24800/50000 (50%)]	Average loss: 0.540987, Accuracy: 0.830083
# Train Epoch: 38 [49600/50000 (99%)]	Average loss: 0.575210, Accuracy: 0.818619
#
# Test set: Average loss: 2.5199, Accuracy: 0.488900
#
# epoch time :  20.42405915260315
#
# Train Epoch: 39 [0/50000 (0%)]	Average loss: 0.670209, Accuracy: 0.782258
# Train Epoch: 39 [24800/50000 (50%)]	Average loss: 0.524128, Accuracy: 0.833052
# Train Epoch: 39 [49600/50000 (99%)]	Average loss: 0.553664, Accuracy: 0.822983
#
# Test set: Average loss: 2.5288, Accuracy: 0.491300
#
# epoch time :  20.544243097305298
#
# Train Epoch: 40 [0/50000 (0%)]	Average loss: 0.598938, Accuracy: 0.798387
# Train Epoch: 40 [24800/50000 (50%)]	Average loss: 0.496241, Accuracy: 0.842642
# Train Epoch: 40 [49600/50000 (99%)]	Average loss: 0.534871, Accuracy: 0.829539
#
# Test set: Average loss: 2.5611, Accuracy: 0.493000
#
# epoch time :  20.420818567276
#
# Train Epoch: 41 [0/50000 (0%)]	Average loss: 0.318805, Accuracy: 0.919355
# Train Epoch: 41 [24800/50000 (50%)]	Average loss: 0.472489, Accuracy: 0.849984
# Train Epoch: 41 [49600/50000 (99%)]	Average loss: 0.504417, Accuracy: 0.838891
#
# Test set: Average loss: 2.5127, Accuracy: 0.498200
#
# best_acc :  0.4981999999999999
#
# epoch time :  20.42271065711975
#
# Train Epoch: 42 [0/50000 (0%)]	Average loss: 0.411913, Accuracy: 0.846774
# Train Epoch: 42 [24800/50000 (50%)]	Average loss: 0.452188, Accuracy: 0.854999
# Train Epoch: 42 [49600/50000 (99%)]	Average loss: 0.476734, Accuracy: 0.846352
#
# Test set: Average loss: 2.6202, Accuracy: 0.490300
#
# epoch time :  20.635056734085083
#
# Train Epoch: 43 [0/50000 (0%)]	Average loss: 0.427424, Accuracy: 0.862903
# Train Epoch: 43 [24800/50000 (50%)]	Average loss: 0.411647, Accuracy: 0.870165
# Train Epoch: 43 [49600/50000 (99%)]	Average loss: 0.441878, Accuracy: 0.858036
#
# Test set: Average loss: 2.6627, Accuracy: 0.489900
#
# epoch time :  20.633617877960205
#
# Train Epoch: 44 [0/50000 (0%)]	Average loss: 0.423879, Accuracy: 0.887097
# Train Epoch: 44 [24800/50000 (50%)]	Average loss: 0.402926, Accuracy: 0.870567
# Train Epoch: 44 [49600/50000 (99%)]	Average loss: 0.428061, Accuracy: 0.861154
#
# Test set: Average loss: 2.6604, Accuracy: 0.493200
#
# epoch time :  20.448017358779907
#
# Train Epoch: 45 [0/50000 (0%)]	Average loss: 0.358938, Accuracy: 0.879032
# Train Epoch: 45 [24800/50000 (50%)]	Average loss: 0.375343, Accuracy: 0.878751
# Train Epoch: 45 [49600/50000 (99%)]	Average loss: 0.403938, Accuracy: 0.869439
#
# Test set: Average loss: 2.6978, Accuracy: 0.493400
#
# epoch time :  20.60716962814331
#
# Train Epoch: 46 [0/50000 (0%)]	Average loss: 0.323090, Accuracy: 0.879032
# Train Epoch: 46 [24800/50000 (50%)]	Average loss: 0.363074, Accuracy: 0.884409
# Train Epoch: 46 [49600/50000 (99%)]	Average loss: 0.379633, Accuracy: 0.877986
#
# Test set: Average loss: 2.7111, Accuracy: 0.501400
#
# best_acc :  0.5014
#
# epoch time :  20.524715423583984
#
# Train Epoch: 47 [0/50000 (0%)]	Average loss: 0.327378, Accuracy: 0.879032
# Train Epoch: 47 [24800/50000 (50%)]	Average loss: 0.335091, Accuracy: 0.891149
# Train Epoch: 47 [49600/50000 (99%)]	Average loss: 0.370740, Accuracy: 0.880219
#
# Test set: Average loss: 2.7078, Accuracy: 0.503400
#
# best_acc :  0.5034000000000001
#
# epoch time :  20.55924892425537
#
# Train Epoch: 48 [0/50000 (0%)]	Average loss: 0.265511, Accuracy: 0.895161
# Train Epoch: 48 [24800/50000 (50%)]	Average loss: 0.319052, Accuracy: 0.898732
# Train Epoch: 48 [49600/50000 (99%)]	Average loss: 0.339127, Accuracy: 0.891039
#
# Test set: Average loss: 2.7412, Accuracy: 0.503500
#
# best_acc :  0.5035000000000001
#
# epoch time :  20.421062707901
#
# Train Epoch: 49 [0/50000 (0%)]	Average loss: 0.197640, Accuracy: 0.927419
# Train Epoch: 49 [24800/50000 (50%)]	Average loss: 0.299011, Accuracy: 0.903948
# Train Epoch: 49 [49600/50000 (99%)]	Average loss: 0.329713, Accuracy: 0.894236
#
# Test set: Average loss: 2.8316, Accuracy: 0.491700
#
# epoch time :  20.376643896102905
#
# Train Epoch: 50 [0/50000 (0%)]	Average loss: 0.273237, Accuracy: 0.943548
# Train Epoch: 50 [24800/50000 (50%)]	Average loss: 0.289463, Accuracy: 0.906877
# Train Epoch: 50 [49600/50000 (99%)]	Average loss: 0.314781, Accuracy: 0.898781
#
# Test set: Average loss: 2.8479, Accuracy: 0.496200
#
# epoch time :  20.71350908279419
#
#
#
# # Best accuracy model(50.35%)

# %% [markdown]
# ## baseline보다 성능 높이기
# - 예시: 네트워크 구조 개선, 하이퍼파라미터 수정 등

# %% [markdown]
# 개선 아이디어 설명:
